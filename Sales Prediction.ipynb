# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from lightgbm import LGBMRegressor

from sklearn import metrics

from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# Data Collection and Processing

# %%
#Read the data
df = pd.read_csv('data/train.csv')

# %%
#See first 10 rows
df.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
# 6            Snack Foods   57.6588            OUT013
# 7            Snack Foods  107.7622            OUT027
# 8           Frozen Foods   96.9726            OUT045
# 9           Frozen Foods  187.8214            OUT017
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
# 5                       2009      Medium               Tier 3
# 6                       1987        High               Tier 3
# 7                       1985      Medium               Tier 3
# 8                       2002         NaN               Tier 2
# 9                       2007         NaN               Tier 2
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052
# 5  Supermarket Type2           556.6088
# 6  Supermarket Type1           343.5528
# 7  Supermarket Type3          4022.7636
# 8  Supermarket Type1          1076.5986
# 9  Supermarket Type1          4710.5350

# %%
#print number of rows and columns
df.shape
# Out:
# (8523, 12)

# %%
#dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# Numerical Features:
#
# Item_Weight,
# Item_Visibility,
# Item_MRP,
# Outlet_Establishment_Year,
# Item_Outlet_Sales

# %% [markdown]
# Categorical Features:
#
# Item_Identifier,
# Item_Fat_Content,
# Item_Type,
# Outlet_Identifier,
# Outlet_Size,
# Outlet_Location_Type,
# Outlet_Type

# %% [markdown]
# Columns that have null values:
#
# Item_Weight,
# Outlet_Size

# %%
#Check for missing values
df.isnull()
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               False        False             False            False
# 1               False        False             False            False
# 2               False        False             False            False
# 3               False        False             False            False
# 4               False        False             False            False
# ...               ...          ...               ...              ...
# 8518            False        False             False            False
# 8519            False        False             False            False
# 8520            False        False             False            False
# 8521            False        False             False            False
# 8522            False        False             False            False
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0         False     False              False                      False
# 1         False     False              False                      False
# 2         False     False              False                      False
# 3         False     False              False                      False
# 4         False     False              False                      False
# ...         ...       ...                ...                        ...
# 8518      False     False              False                      False
# 8519      False     False              False                      False
# 8520      False     False              False                      False
# 8521      False     False              False                      False
# 8522      False     False              False                      False
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0           False                 False        False              False
# 1           False                 False        False              False
# 2           False                 False        False              False
# 3            True                 False        False              False
# 4           False                 False        False              False
# ...           ...                   ...          ...                ...
# 8518        False                 False        False              False
# 8519         True                 False        False              False
# 8520        False                 False        False              False
# 8521        False                 False        False              False
# 8522        False                 False        False              False
#
# [8523 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# Handling Missing Values
# Mean Method to handle Missing Values in Item_Weight

# %%
#Calculate Mean of Item_Weight column
df['Item_Weight'].mean()
# Out:
# 12.857645184135976

# %%
#Fill missing values in Item_Weight column with mean
df['Item_Weight'].fillna(df['Item_Weight'].mean(), inplace=True)

# %%
#Check for missing values
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# Handling Missing Values

# %% [markdown]
# Mode Method to handle Missing Values in Outlet_Size

# %%
df['Outlet_Size'].value_counts()
# Out:
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: count, dtype: int64

# %%
#Calculate mode of Outlet_Size column for each Outlet_Type in Outlet_Size
df.groupby('Outlet_Type')['Outlet_Size'].agg(pd.Series.mode)
# Out:
# Outlet_Type
# Grocery Store         Small
# Supermarket Type1     Small
# Supermarket Type2    Medium
# Supermarket Type3    Medium
# Name: Outlet_Size, dtype: object

# %% [markdown]
# #Fill missing values in Outlet_Size column with mode of Outlet_Size
# column for each Outlet_Type in Outlet_Size

# %%
df.loc[df['Outlet_Type']=='Grocery Store','Outlet_Size']='Small'
df.loc[df['Outlet_Type']=='Supermarket Type1','Outlet_Size']='Small'
df.loc[df['Outlet_Type']=='Supermarket Type2','Outlet_Size']='Medium'
df.loc[df['Outlet_Type']=='Supermarket Type3','Outlet_Size']='Medium'

# %%
#Check for missing values
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# Data Analysis

# %%
#See descriptive statistics of numerical columns
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.226124         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.310000         0.026989    93.826500                1987.000000
# 50%      12.857645         0.053931   143.012800                1999.000000
# 75%      16.000000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
# Data Visualization of Numerical Features

# %%
#applying Seaborn's default aesthetic settings to your plots
sns.set()

# %%
#Plot distplot for numerical columns
cols = ['Item_Weight','Item_Visibility','Item_MRP','Item_Outlet_Sales']
for col in cols:
    plt.figure(figsize=(10,5))
    sns.distplot(df[col])
    plt.show()

# %%
#Plot countplot for Outlet_Establishment_Year column
plt.figure(figsize=(10,5))
sns.countplot(x='Outlet_Establishment_Year', data=df)
plt.show()

# %% [markdown]
# Data Visualization of Categorical Features

# %%
#Plot countplot for Item_Fat_Content column
plt.figure(figsize=(10,5))
sns.countplot(x= "Item_Fat_Content" , data=df)
plt.show()

# %%
#Plot countplot for Item_Type column
plt.figure(figsize=(30,10))
sns.countplot(x= "Item_Type" , data=df)
plt.show()

# %%
#Plot countplot for Outlet_Size column
plt.figure(figsize=(10,5))
sns.countplot(x= "Outlet_Size" , data=df)
plt.show()

# %%
#Plot countplot for Outlet_Location_Type column
plt.figure(figsize=(10,5))
sns.countplot(x= "Outlet_Location_Type" , data=df)
plt.show()

# %%
#Plot countplot for Outlet_Type column
plt.figure(figsize=(10,5))
sns.countplot(x= "Outlet_Type" , data=df)
plt.show()

# %% [markdown]
# Data Preprocessing

# %%
#see categories in Item_Fat_Content column
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
#handle Item_Fat_Content column categories with replacement
df['Item_Fat_Content'].replace({'LF':'Low Fat','reg':'Regular','low fat':'Low Fat'},inplace=True)

# %%
#see categories in Item_Fat_Content column
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %% [markdown]
# Handle Categorical Features

# %%
le = LabelEncoder()

df['Item_Fat_Content'] = le.fit_transform(df['Item_Fat_Content'])

df['Item_Type'] = le.fit_transform(df['Item_Type'])

df['Outlet_Size'] = le.fit_transform(df['Outlet_Size'])

df['Outlet_Location_Type'] = le.fit_transform(df['Outlet_Location_Type'])

df['Outlet_Type'] = le.fit_transform(df['Outlet_Type'])

df['Item_Identifier'] = le.fit_transform(df['Item_Identifier'])

df['Outlet_Identifier'] = le.fit_transform(df['Outlet_Identifier'])

# %%
df.head(10)
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156     9.300000                 0         0.016047          4
# 1                8     5.920000                 1         0.019278         14
# 2              662    17.500000                 0         0.016760         10
# 3             1121    19.200000                 1         0.000000          6
# 4             1297     8.930000                 0         0.000000          9
# 5              758    10.395000                 1         0.000000          0
# 6              696    13.650000                 1         0.012741         13
# 7              738    12.857645                 0         0.127470         13
# 8              440    16.200000                 1         0.016687          5
# 9              990    19.200000                 1         0.094450          5
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999            1
# 1   48.2692                  3                       2009            0
# 2  141.6180                  9                       1999            1
# 3  182.0950                  0                       1998            1
# 4   53.8614                  1                       1987            1
# 5   51.4008                  3                       2009            0
# 6   57.6588                  1                       1987            1
# 7  107.7622                  5                       1985            0
# 8   96.9726                  7                       2002            1
# 9  187.8214                  2                       2007            1
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0                     0            1          3735.1380
# 1                     2            2           443.4228
# 2                     0            1          2097.2700
# 3                     2            0           732.3800
# 4                     2            1           994.7052
# 5                     2            2           556.6088
# 6                     2            1           343.5528
# 7                     2            3          4022.7636
# 8                     1            1          1076.5986
# 9                     1            1          4710.5350

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   int32
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   int64
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   int64
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   int32
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   int64
#  9   Outlet_Location_Type       8523 non-null   int64
#  10  Outlet_Type                8523 non-null   int64
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int32(2), int64(6)
# memory usage: 732.6 KB

# %% [markdown]
# Data Scaling using StandardScaler

# %%
sc = StandardScaler()

df['Item_Weight'] = sc.fit_transform(df['Item_Weight'].values.reshape(-1,1))

df['Item_Visibility'] = sc.fit_transform(df['Item_Visibility'].values.reshape(-1,1))

df['Item_MRP'] = sc.fit_transform(df['Item_MRP'].values.reshape(-1,1))

df['Item_Outlet_Sales'] = sc.fit_transform(df['Item_Outlet_Sales'].values.reshape(-1,1))

df.head(10)
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156    -0.841872                 0        -0.970732          4
# 1                8    -1.641706                 1        -0.908111         14
# 2              662     1.098554                 0        -0.956917         10
# 3             1121     1.500838                 1        -1.281758          6
# 4             1297    -0.929428                 0        -1.281758          9
# 5              758    -0.582754                 1        -1.281758          0
# 6              696     0.187501                 1        -1.034813         13
# 7              738     0.000000                 0         1.188838         13
# 8              440     0.790926                 1        -0.958331          5
# 9              990     1.500838                 1         0.548845          5
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  1.747454                  9                       1999            1
# 1 -1.489023                  3                       2009            0
# 2  0.010040                  9                       1999            1
# 3  0.660050                  0                       1998            1
# 4 -1.399220                  1                       1987            1
# 5 -1.438734                  3                       2009            0
# 6 -1.338238                  1                       1987            1
# 7 -0.533641                  5                       1985            0
# 8 -0.706908                  7                       2002            1
# 9  0.752008                  2                       2007            1
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0                     0            1           0.910601
# 1                     2            2          -1.018440
# 2                     0            1          -0.049238
# 3                     2            0          -0.849103
# 4                     2            1          -0.695373
# 5                     2            2          -0.952110
# 6                     2            1          -1.076967
# 7                     2            3           1.079158
# 8                     1            1          -0.647381
# 9                     1            1           1.482212

# %% [markdown]
# Seperate Features from Label

# %%
#sepertate features and target

Features = df.drop(columns=['Item_Outlet_Sales'])

Target = df['Item_Outlet_Sales']

# %%
Features
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156    -0.841872                 0        -0.970732
# 1                   8    -1.641706                 1        -0.908111
# 2                 662     1.098554                 0        -0.956917
# 3                1121     1.500838                 1        -1.281758
# 4                1297    -0.929428                 0        -1.281758
# ...               ...          ...               ...              ...
# 8518              370    -1.418084                 0        -0.181193
# 8519              897    -1.059578                 1        -0.371154
# 8520             1357    -0.534243                 0        -0.599784
# 8521              681    -1.336444                 1         1.532880
# 8522               50     0.459634                 0        -0.411936
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0             4  1.747454                  9                       1999
# 1            14 -1.489023                  3                       2009
# 2            10  0.010040                  9                       1999
# 3             6  0.660050                  0                       1998
# 4             9 -1.399220                  1                       1987
# ...         ...       ...                ...                        ...
# 8518         13  1.180783                  1                       1987
# 8519          0 -0.527301                  7                       2002
# 8520          8 -0.897208                  6                       2004
# 8521         13 -0.607977                  3                       2009
# 8522         14 -1.052261                  8                       1997
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0               1                     0            1
# 1               0                     2            2
# 2               1                     0            1
# 3               1                     2            0
# 4               1                     2            1
# ...           ...                   ...          ...
# 8518            1                     2            1
# 8519            1                     1            1
# 8520            1                     1            1
# 8521            0                     2            2
# 8522            1                     0            1
#
# [8523 rows x 11 columns]

# %%
Target
# Out:
# 0       0.910601
# 1      -1.018440
# 2      -0.049238
# 3      -0.849103
# 4      -0.695373
#           ...
# 8518    0.349915
# 8519   -0.956402
# 8520   -0.579100
# 8521   -0.196725
# 8522   -0.829594
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %% [markdown]
# Split data into train and test sets

# %%
#splittting data into training and testing data
Features_train,Features_test,Target_train,Target_test = train_test_split(Features,Target,test_size=0.2,random_state=42)

# %%
#print shape of features and training and testing data of features
print("Shape of Feature:",Features.shape)
print("Shape of Feature_train:",Features_train.shape)
print("Shape of Feature_test:",Features_test.shape)
# Out:
# Shape of Feature: (8523, 11)
# Shape of Feature_train: (6818, 11)
# Shape of Feature_test: (1705, 11)

# %%
#print shape of Target and training and testing data of Target
print("Shape of Target:",Target.shape)
print("Shape of Target_train:",Target_train.shape)
print("Shape of Target_test:",Target_test.shape)
# Out:
# Shape of Target: (8523,)
# Shape of Target_train: (6818,)
# Shape of Target_test: (1705,)

# %% [markdown]
# Building Model

# %% [markdown]
# Building XGBRegressor Model

# %%
#build model with XGBRegressor
XGBRModel = XGBRegressor()

#fit the model
XGBRModel.fit(Features_train,Target_train)

#predict the model
Target_pred = XGBRModel.predict(Features_test)

#calculate R-Squared
r2_score = metrics.r2_score(Target_test,Target_pred)
print("R-Squared:",r2_score)

#calculate Mean Absolute Error
mae = metrics.mean_absolute_error(Target_test,Target_pred)
print("Mean Absolute Error:",mae)

#calculate Mean Squared Error
mse = metrics.mean_squared_error(Target_test,Target_pred)
print("Mean Squared Error:",mse)
# Out:
# R-Squared: 0.5119126417237851
# Mean Absolute Error: 0.47173654608004656
# Mean Squared Error: 0.45559693922553346

# %% [markdown]
# Building SVR Model

# %%
#build model with SVLRegressor
model = SVR()

#fit the model
model.fit(Features_train,Target_train)

#predict the model
Target_pred = model.predict(Features_test)

#calculate R-Squared
r2_score = metrics.r2_score(Target_test,Target_pred)
print("R-Squared:",r2_score)

#calculate Mean Absolute Error
mae = metrics.mean_absolute_error(Target_test,Target_pred)
print("Mean Absolute Error:",mae)

#calculate Mean Squared Error
mse = metrics.mean_squared_error(Target_test,Target_pred)
print("Mean Squared Error:",mse)
# Out:
# R-Squared: -0.02444700281512735
# Mean Absolute Error: 0.7432809334031226
# Mean Squared Error: 0.9562528325456283

# %% [markdown]
# Building RandomForestRegressor Model

# %%
#build model with RandomForestRegressor
model = RandomForestRegressor()

#fit the model
model.fit(Features_train,Target_train)

#predict the model
Target_pred = model.predict(Features_test)

#calculate R-Squared
r2_score = metrics.r2_score(Target_test,Target_pred)
print("R-Squared:",r2_score)

#calculate Mean Absolute Error
mae = metrics.mean_absolute_error(Target_test,Target_pred)
print("Mean Absolute Error:",mae)

#calculate Mean Squared Error
mse = metrics.mean_squared_error(Target_test,Target_pred)
print("Mean Squared Error:",mse)
# Out:
# R-Squared: 0.5600539638988872
# Mean Absolute Error: 0.4462811828735367
# Mean Squared Error: 0.41066023135686824

# %%
#Build Lazy Predict Model
from lazypredict.Supervised import LazyRegressor

#Build Lazy Predict Model
reg = LazyRegressor(verbose=0,ignore_warnings=False,custom_metric=None)
models,predictions = reg.fit(Features_train,Features_test,Target_train,Target_test)

#Print model performance
print(models)
# Out:
#  21%|█████████████████▊                                                                 | 9/42 [00:05<00:28,  1.16it/s]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
#  74%|████████████████████████████████████████████████████████████▌                     | 31/42 [00:28<00:05,  2.00it/s]
# PoissonRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# QuantileRegressor model failed to execute
# Solver interior-point is not anymore available in SciPy >= 1.11.0.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [00:42<00:00,  1.00s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000730 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1045
# [LightGBM] [Info] Number of data points in the train set: 6818, number of used features: 11
# [LightGBM] [Info] Start training from score 0.012351
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# NuSVR                                        0.61       0.61  0.60        2.31
# SVR                                          0.61       0.61  0.60        2.68
# MLPRegressor                                 0.61       0.61  0.61        3.21
# GradientBoostingRegressor                    0.60       0.60  0.61        2.36
# LGBMRegressor                                0.59       0.59  0.62        0.20
# HistGradientBoostingRegressor                0.58       0.59  0.62        1.35
# Lars                                         0.58       0.58  0.63        0.13
# LarsCV                                       0.58       0.58  0.63        0.38
# LassoLarsIC                                  0.58       0.58  0.63        0.02
# TransformedTargetRegressor                   0.58       0.58  0.63        0.14
# LinearRegression                             0.58       0.58  0.63        0.01
# Ridge                                        0.58       0.58  0.63        0.01
# RidgeCV                                      0.58       0.58  0.63        0.02
# KernelRidge                                  0.58       0.58  0.63        3.22
# BayesianRidge                                0.58       0.58  0.63        0.11
# ElasticNetCV                                 0.58       0.58  0.63        0.10
# LassoLarsCV                                  0.58       0.58  0.63        0.03
# LassoCV                                      0.58       0.58  0.63        0.10
# OrthogonalMatchingPursuitCV                  0.58       0.58  0.63        0.12
# SGDRegressor                                 0.58       0.58  0.63        0.02
# HuberRegressor                               0.57       0.58  0.63        0.12
# LinearSVR                                    0.57       0.57  0.63        0.06
# RandomForestRegressor                        0.55       0.56  0.64        9.43
# ExtraTreesRegressor                          0.55       0.55  0.65        4.05
# BaggingRegressor                             0.52       0.52  0.67        0.97
# XGBRegressor                                 0.51       0.51  0.67        0.23
# RANSACRegressor                              0.50       0.51  0.68        0.46
# KNeighborsRegressor                          0.50       0.50  0.68        0.14
# AdaBoostRegressor                            0.40       0.41  0.74        0.54
# TweedieRegressor                             0.39       0.39  0.75        0.19
# OrthogonalMatchingPursuit                    0.33       0.33  0.79        0.02
# DecisionTreeRegressor                        0.20       0.20  0.86        0.13
# PassiveAggressiveRegressor                   0.08       0.09  0.92        0.10
# ExtraTreeRegressor                           0.07       0.07  0.93        0.05
# ElasticNet                                   0.04       0.05  0.94        0.02
# Lasso                                       -0.01      -0.00  0.97        0.01
# DummyRegressor                              -0.01      -0.00  0.97        0.02
# LassoLars                                   -0.01      -0.00  0.97        0.01
# GaussianProcessRegressor                   -61.37     -60.97  7.61        9.08

# %%
#build model with GradientBoostingRegressor
model = GradientBoostingRegressor()

#fit the model
model.fit(Features_train,Target_train)

#predict the model
Target_pred = model.predict(Features_test)

#calculate R-Squared
r2_score = metrics.r2_score(Target_test,Target_pred)
print("R-Squared:",r2_score)

#calculate Mean Absolute Error
mae = metrics.mean_absolute_error(Target_test,Target_pred)
print("Mean Absolute Error:",mae)

#calculate Mean Squared Error
mse = metrics.mean_squared_error(Target_test,Target_pred)
print("Mean Squared Error:",mse)
# Out:
# R-Squared: 0.6036993866378026
# Mean Absolute Error: 0.4246063354835057
# Mean Squared Error: 0.369920145235233

# %%
#build model with LGBMRegressor
model = LGBMRegressor()

#fit the model
model.fit(Features_train,Target_train)

#predict the model
Target_pred = model.predict(Features_test)

#calculate R-Squared
r2_score = metrics.r2_score(Target_test,Target_pred)
print("R-Squared:",r2_score)

#calculate Mean Absolute Error
mae = metrics.mean_absolute_error(Target_test,Target_pred)
print("Mean Absolute Error:",mae)

#calculate Mean Squared Error
mse = metrics.mean_squared_error(Target_test,Target_pred)
print("Mean Squared Error:",mse)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000250 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1027
# [LightGBM] [Info] Number of data points in the train set: 6818, number of used features: 11
# [LightGBM] [Info] Start training from score 0.012351
# R-Squared: 0.5865680743618109
# Mean Absolute Error: 0.43394911824178806
# Mean Squared Error: 0.3859110806805262

# %%
#Save the model
from joblib import dump
dump(XGBRModel, 'XGBRegressor.joblib')
# Out:
# ['XGBRegressor.joblib']

# %% [markdown]
# Make a predictive System

# %%
df = pd.read_csv('data/test.csv')
df.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDW58        20.75          Low Fat             0.01
# 1           FDW14         8.30              reg             0.04
# 2           NCN55        14.60          Low Fat             0.10
# 3           FDQ58         7.32          Low Fat             0.02
# 4           FDY38          NaN          Regular             0.12
# 5           FDH56         9.80          Regular             0.06
# 6           FDL48        19.35          Regular             0.08
# 7           FDC48          NaN          Low Fat             0.02
# 8           FDN33         6.30          Regular             0.12
# 9           FDA36         5.99          Low Fat             0.01
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods    107.86            OUT049
# 1                  Dairy     87.32            OUT017
# 2                 Others    241.75            OUT010
# 3            Snack Foods    155.03            OUT017
# 4                  Dairy    234.23            OUT027
# 5  Fruits and Vegetables    117.15            OUT046
# 6           Baking Goods     50.10            OUT018
# 7           Baking Goods     81.06            OUT027
# 8            Snack Foods     95.74            OUT045
# 9           Baking Goods    186.89            OUT017
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2007         NaN               Tier 2
# 2                       1998         NaN               Tier 3
# 3                       2007         NaN               Tier 2
# 4                       1985      Medium               Tier 3
# 5                       1997       Small               Tier 1
# 6                       2009      Medium               Tier 3
# 7                       1985      Medium               Tier 3
# 8                       2002         NaN               Tier 2
# 9                       2007         NaN               Tier 2
#
#          Outlet_Type
# 0  Supermarket Type1
# 1  Supermarket Type1
# 2      Grocery Store
# 3  Supermarket Type1
# 4  Supermarket Type3
# 5  Supermarket Type1
# 6  Supermarket Type2
# 7  Supermarket Type3
# 8  Supermarket Type1
# 9  Supermarket Type1

# %%
df.shape
# Out:
# (5681, 11)

# %% [markdown]
# PreProcessing test data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
#see categories in Item_Fat_Content column
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    3396
# Regular    1935
# LF          206
# reg          78
# low fat      66
# Name: count, dtype: int64

# %%
#handle Item_Fat_Content column categories with replacement
df['Item_Fat_Content'].replace({'LF':'Low Fat','reg':'Regular','low fat':'Low Fat'},inplace=True)

# %%
#see categories in Item_Fat_Content column
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    3668
# Regular    2013
# Name: count, dtype: int64

# %%
#Apply Label Encoding on categorical columns
le = LabelEncoder()

df['Item_Fat_Content'] = le.fit_transform(df['Item_Fat_Content'])

df['Item_Type'] = le.fit_transform(df['Item_Type'])

df['Outlet_Size'] = le.fit_transform(df['Outlet_Size'])

df['Outlet_Location_Type'] = le.fit_transform(df['Outlet_Location_Type'])

df['Outlet_Type'] = le.fit_transform(df['Outlet_Type'])

df['Item_Identifier'] = le.fit_transform(df['Item_Identifier'])

df['Outlet_Identifier'] = le.fit_transform(df['Outlet_Identifier'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   int32
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   int32
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   int32
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   int32
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                5681 non-null   int32
#  9   Outlet_Location_Type       5681 non-null   int32
#  10  Outlet_Type                5681 non-null   int32
# dtypes: float64(3), int32(7), int64(1)
# memory usage: 333.0 KB

# %%
sc = StandardScaler()

df['Item_Weight'] = sc.fit_transform(df['Item_Weight'].values.reshape(-1,1))

df['Item_Visibility'] = sc.fit_transform(df['Item_Visibility'].values.reshape(-1,1))

df['Item_MRP'] = sc.fit_transform(df['Item_MRP'].values.reshape(-1,1))

df.head(10)
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0             1103         1.73                 0            -1.13         13
# 1             1067        -0.94                 1            -0.53          4
# 2             1406         0.41                 0             0.66         11
# 3              809        -1.15                 0            -0.98         13
# 4             1184          NaN                 1             1.03          4
# 5              461        -0.62                 1            -0.04          6
# 6              604         1.43                 1             0.33          0
# 7              266          NaN                 0            -0.97          0
# 8              668        -1.37                 1             1.13         13
# 9              170        -1.44                 0            -1.17          0
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0     -0.54                  9                       1999            1
# 1     -0.87                  2                       2007            3
# 2      1.63                  0                       1998            3
# 3      0.23                  2                       2007            3
# 4      1.51                  5                       1985            1
# 5     -0.39                  8                       1997            2
# 6     -1.47                  3                       2009            1
# 7     -0.97                  5                       1985            1
# 8     -0.73                  7                       2002            3
# 9      0.74                  2                       2007            3
#
#    Outlet_Location_Type  Outlet_Type
# 0                     0            1
# 1                     1            1
# 2                     2            0
# 3                     1            1
# 4                     2            3
# 5                     0            1
# 6                     2            2
# 7                     2            3
# 8                     1            1
# 9                     1            1

# %%
#load trained model
from joblib import load

model = load('XGBRegressor.joblib')

#predict the model
Target_pred = model.predict(df)

# %%
#print each Item_Identifier with its predicted value and put the result in dataframe
df = pd.DataFrame({'Item_Identifier':df['Item_Identifier'],'Item_Outlet_Sales':Target_pred})
df
# Out:
#       Item_Identifier  Item_Outlet_Sales
# 0                1103              -0.32
# 1                1067              -0.57
# 2                1406              -1.09
# 3                 809               0.08
# 4                1184               3.16
# ...               ...                ...
# 5676              231               0.10
# 5677              306              -0.16
# 5678             1412               0.02
# 5679              517               1.22
# 5680              987              -0.34
#
# [5681 rows x 2 columns]
